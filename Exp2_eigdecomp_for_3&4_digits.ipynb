# %% [markdown]
# Exp 2: experiment for 3 and 4 digits:

# %%
from eig_plots import plot_eigval,plot_pairs,plot_eigvec_3d,eigdecomp
import numpy as np
import matplotlib.pyplot as plt
from networks import cnn,res_cnn

# %% [markdown]
# 3 digits:

# %%
n_samples=800
digits=[3,5,8]
idx=''.join(map(str,digits))

# %%
cnn3=cnn(3)
U3_cnn,S3_cnn,V3_cnn=eigdecomp(cnn3,digits,n_samples)

# %%
plt.figure(figsize=(7,5))
plot_pairs(digits,U3_cnn,n_samples)
plt.savefig(f'./digit{idx}cnn_3l.png')

# %%
# %matplotlib inline
plot_eigvec_3d(digits,U3_cnn,n_samples)
plt.savefig(f'./eigvec{idx}cnn_3l.png')

# %%
plot_eigval(S3_cnn)

# %% [markdown]
# 4 digits:

# %%
n_samples=1000
digits=[1,3,5,8]
idx=''.join(map(str,digits))

# %%
U3_cnn,S3_cnn,V3_cnn=eigdecomp(cnn3,digits,n_samples)

# %%
plt.figure(figsize=(7,5))
plot_pairs(digits,U3_cnn,n_samples)
plt.savefig(f'./digit{idx}cnn_3l.png')

# %%
# %matplotlib inline
plot_eigvec_3d(digits,U3_cnn,n_samples,view=(18,230))
plt.savefig(f'./eigvec{idx}cnn_3l.png')

# %%
plot_eigval(S3_cnn)
